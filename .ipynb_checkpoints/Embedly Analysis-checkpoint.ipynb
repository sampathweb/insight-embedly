# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from app.settings import DevConfig
import ggplot as gg

# %%
# %matplotlib inline

# %%
config = DevConfig()

# %%
db_engine = create_engine(config.SQLALCHEMY_DATABASE_URI)

# %%
df = pd.read_sql_query('select client_host, count(*) from events group by client_host having count(*) > 50', db_engine)

# %%
p = gg.ggplot(df, gg.aes(x='count')) + gg.geom_bar()

# %%
p
# Out:
# stat_bin: binwidth defaulted to range/30.
#     Use 'binwidth = x' to adjust this.
# <ggplot: (301209129)>

# %%
df
# Out:
#                             client_host   count
# 0                        lockerdome.com  129838
# 1                          linkedin.com   17127
# 2                  kisskissbankbank.com   10101
# 3                            disqus.com  438592
# 4                            medium.com   57639
# 5                        rap.genius.com  162570
# 6                            change.org   41714
# 7                        pop.genius.com    7332
# 8                          thrillon.com   65965
# 9                thejesuscallingapp.com     270
# 10                        embed.edim.co   19429
# 11                          themuse.com    1784
# 12                         x.genius.com     369
# 13                        blog.embed.ly    1961
# 14                   filmsforaction.org   30750
# 15                           buzzpo.com   21772
# 16                     knowyourmeme.com   34817
# 17                  na20.salesforce.com     179
# 18                           edmodo.com   62854
# ...

# %%
gg.diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5     55    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8     61    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9     65    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4     58    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3     58    335  4.34  4.35  2.75

# %%
p = gg.ggplot(gg.aes(x='depth', y='price'), data=gg.diamonds) + gg.geom_point()
p
# Out:
# <ggplot: (294646137)>
